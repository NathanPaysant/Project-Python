# %% [markdown]
# <a href="https://colab.research.google.com/github/NathanPaysant/Project-Python/blob/master/Handle_financial_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q quandl

import quandl
import pandas as pd
import pandas_datareader as web
import numpy
import matplotlib as plt
import datetime

# %%
start = datetime.datetime(2018,1,1)
end = datetime.date.today()

apple = quandl.get("EOD/AAPL", authtoken="GvgoCpL_VyoemHwaMjB9").loc['2017-09-23' : ]

type(apple)

apple
# Out:
#                Open      High       Low   Close      Volume  Dividend  Split  \
# Date
# 2017-09-25  149.990  151.8300  149.1600  150.55  44387336.0       0.0    1.0
# 2017-09-26  151.780  153.9200  151.6900  153.14  36660045.0       0.0    1.0
# 2017-09-27  153.800  154.7189  153.5400  154.23  25504227.0       0.0    1.0
# 2017-09-28  153.890  154.2800  152.7000  153.28  22005455.0       0.0    1.0
# 2017-09-29  153.210  154.1300  152.0000  154.12  26299810.0       0.0    1.0
# 2017-10-02  154.260  154.4500  152.7200  153.81  18698842.0       0.0    1.0
# 2017-10-03  154.010  155.0900  153.9100  154.48  16230293.0       0.0    1.0
# 2017-10-04  153.630  153.8600  152.4600  153.48  20163750.0       0.0    1.0
# 2017-10-05  154.180  155.4400  154.0500  155.39  21283769.0       0.0    1.0
# 2017-10-06  154.970  155.4900  154.5600  155.30  17407558.0       0.0    1.0
# 2017-10-09  155.810  156.7300  155.4850  155.84  16262923.0       0.0    1.0
# ...

# %%
Apple = apple['2018-01-01':]
stockprice = Apple['Close']
M = stockprice.mean()

stockprice.plot()
[,M].plot()
# Out:
#   File "<ipython-input-46-15e9874f3cde>", line 6
#     [,M].plot()
#      ^
# SyntaxError: invalid syntax

# %%
Apple['100days'] = means
